# %%
import pandas as pd

file = "VF.txt"
# Try common encodings
encodings = ["utf-8", "latin1", "iso-8859-1", "cp1252"]

for enc in encodings:
    try:
        df = pd.read_csv(file, sep='|', decimal=',', encoding=enc)
        print(f"Success with encoding: {enc}")
        break
    except UnicodeDecodeError:
        continue

# Save as .xls
df.to_excel("VF1.xlsx", index=False, engine="openpyxl")
# Out:
# C:\Users\wambo\AppData\Local\Temp\ipykernel_37776\800772335.py:9: DtypeWarning: Columns (18,23,24,26,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file, sep='|', decimal=',', encoding=enc)
# Success with encoding: utf-8
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 16
#      13         continue
#      15 # Save as .xls
# ---> 16 df.to_excel("VF1.xlsx", index=False, engine="openpyxl")
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# ...

# %%
import pandas as pd
