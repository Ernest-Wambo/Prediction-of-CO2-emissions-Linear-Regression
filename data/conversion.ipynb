# %%
import pandas as pd

file = "CO2csv.csv"

# Try common encodings
encodings = ["utf-8", "latin1", "iso-8859-1", "cp1252"]

for enc in encodings:
    try:
        df = pd.read_csv(file, encoding=enc, sep=';')
        print(f"Success with encoding: {enc}")
        break
    except UnicodeDecodeError:
        continue

# Save as .xls
df.to_excel("CO2.xls", index=False, engine="xlwt")
# Out:
# Success with encoding: latin1
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\wambo\anaconda3\Lib\site-packages\pandas\io\excel\_util.py:93, in get_writer(engine_name)
#      92 try:
# ---> 93     return _writers[engine_name]
#      94 except KeyError as err:
#
# KeyError: 'xlwt'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 17
#      14         continue
#      16 # Save as .xls
# ---> 17 df.to_excel("CO2.xls", index=False, engine="xlwt")
#
# File c:\Users\wambo\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
# ...

# %%
import pandas as pd

file = "data/CO2csv.csv"

# Try common encodings
encodings = ["utf-8", "latin1", "iso-8859-1", "cp1252"]

for enc in encodings:
    try:
        df = pd.read_csv(file, encoding=enc, sep=';')
        print(f"Success with encoding: {enc}")
        break
    except UnicodeDecodeError:
        continue

# Save as .xls
df.to_excel("CO2.xls", index=False, engine="xlwt")
